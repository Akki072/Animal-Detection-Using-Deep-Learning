# %%
import torch
from PIL import Image

# Load the model
model = torch.hub.load('ultralytics/yolov5', 'custom',r"C:\Users\aakas\yolov5\runs\train\exp4\weights\best.pt")  
# Load the image
img = Image.open(r"D:\Download\DatasetYolo\images\val\026_zebra.jpg") 
# Perform inference
results = model(img)

# Filter results to only include your classes of interest
your_classes = ['buffalo','elephant','rhino','zebra']  # update with your classes
filtered_results = [result for result in results.xyxy[0] if result[-1] in your_classes]

# Print the results
for result in filtered_results:
    print(f"Detected a {result[-1]} with a confidence of {result[-2]} at location {result[:4]}")
# Out:
# Using cache found in C:\Users\aakas/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-5-7 Python-3.8.19 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
import torch
from PIL import Image

# Load the model with custom weights
model = torch.hub.load('ultralytics/yolov5', 'yolov5s',r"C:\Users\aakas\yolov5\runs\train\exp4\weights\best.pt")  # update with your weights path

# Load the image
img = Image.open(r"D:\Download\DatasetResnet\val\zebra\327_zebra.jpg")  # update with your image path

# Perform inference
results = model(img)

# Print the results
results.print()  # prints results to screen
results.show()  # displays results
# Out:
# Using cache found in C:\Users\aakas/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-5-7 Python-3.8.19 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 412x550 5 zebras
# Speed: 4.0ms pre-process, 47.0ms inference, 147.8ms NMS per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=550x412>

# %%
import os
import torch
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
